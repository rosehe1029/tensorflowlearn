# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
import tensorflow as tf
aa=tf.constant(1.2)

# %%
aa
# Out:
# <tf.Tensor: id=0, shape=(), dtype=float32, numpy=1.2>

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
import keras
(x_train,y_train),(x_test,y_test)=keras.datasets.imdb.load_data(num_words=10000)
# Out:
# Using TensorFlow backend.
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 599dadb1135973df5b59232a0e9a887c so we will re-download the data.
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# D:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# D:\anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# D:\anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# D:\anaconda\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# D:\anaconda\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# D:\anaconda\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# D:\anaconda\lib\http\client.py in connect(self)
#    1399             self.sock = self._context.wrap_socket(self.sock,
# -> 1400                                                   server_hostname=server_hostname)
#    1401             if not self._context.check_hostname and self._check_hostname:
#
# D:\anaconda\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#
# D:\anaconda\lib\ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     813                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 814                     self.do_handshake()
#     815
#
# D:\anaconda\lib\ssl.py in do_handshake(self, block)
#    1067                 self.settimeout(None)
# -> 1068             self._sslobj.do_handshake()
#    1069         finally:
#
# D:\anaconda\lib\ssl.py in do_handshake(self)
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     224             try:
# --> 225                 urlretrieve(origin, fpath, dl_progress)
#     226             except HTTPError as e:
#
# D:\anaconda\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#
# D:\anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# D:\anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     525
# --> 526         response = self._open(req, data)
#     527
#
# D:\anaconda\lib\urllib\request.py in _open(self, req, data)
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#
# D:\anaconda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# D:\anaconda\lib\urllib\request.py in https_open(self, req)
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#
# D:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#
# URLError: <urlopen error [WinError 10054] 远程主机强迫关闭了一个现有的连接。>
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-ac2aac242c7d> in <module>()
#       1 import keras
# ----> 2 (x_train,y_train),(x_test,y_test)=keras.datasets.imdb.load_data(num_words=10000)
#
# D:\anaconda\lib\site-packages\keras\datasets\imdb.py in load_data(path, num_words, skip_top, maxlen, seed, start_char, oov_char, index_from, **kwargs)
#      55     path = get_file(path,
#      56                     origin='https://s3.amazonaws.com/text-datasets/imdb.npz',
# ---> 57                     file_hash='599dadb1135973df5b59232a0e9a887c')
#      58     with np.load(path, allow_pickle=True) as f:
#      59         x_train, labels_train = f['x_train'], f['y_train']
#
# D:\anaconda\lib\site-packages\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     227                 raise Exception(error_msg.format(origin, e.code, e.msg))
#     228             except URLError as e:
# --> 229                 raise Exception(error_msg.format(origin, e.errno, e.reason))
#     230         except (Exception, KeyboardInterrupt):
#     231             if os.path.exists(fpath):
#
# Exception: URL fetch failure on https://s3.amazonaws.com/text-datasets/imdb.npz : None -- [WinError 10054] 远程主机强迫关闭了一个现有的连接。

# %%
x=tf.constant([1.,2.])
x=10**x

# %%
tf.math.log(x)/tf.math.log(10.)
# Out:
# <tf.Tensor: id=151, shape=(2,), dtype=float32, numpy=array([1., 2.], dtype=float32)>

# %%
a=tf.random.normal([4,3,23,32])
b=tf.random.normal([4,3,32,2])

# %%
a@b
# Out:
#          [ 3.99193335e+00,  6.04195404e+00]],
#
#         [[-1.31418276e+00, -2.12134123e-01],
#          [-3.27308083e+00,  2.66275024e+00],
#          [-2.28303552e+00, -3.89640546e+00],
#          [-7.26476908e+00, -4.30549574e+00],
#          [-2.37176895e+00, -1.33929920e+00],
#          [-1.52474165e-01, -4.99435902e+00],
#          [-5.25641775e+00, -1.50379944e+00],
#          [-4.95300865e+00, -5.15689421e+00],
#          [ 2.31087613e+00,  2.44088793e+00],
#          [ 3.17018628e+00, -3.06762552e+00],
#          [-1.59254742e+00,  9.00240958e-01],
#          [-7.81735992e+00,  2.65056372e+00],
#          [ 4.07119036e+00,  5.88015079e+00],
#          [-5.55245399e+00, -2.56640816e+00],
#          [ 3.32202578e+00, -3.96292520e+00],
#          [ 5.10301018e+00, -1.82035637e+00],
#          [ 5.90352821e+00, -9.74082470e-01],
#          [-6.58275127e-01,  2.59160447e+00],
#          [-9.29645157e+00,  2.12942505e+00],
#          [-4.26870060e+00, -7.24434853e-02],
#          [-4.59306002e+00, -2.22097588e+00],
#          [-1.97982144e+00, -6.38092661e+00],
#          [ 8.63931084e+00, -3.37117362e+00]]]], dtype=float32)>

# %%
tf.matmul(a,b)
# Out:
# <tf.Tensor: id=165, shape=(4, 3, 23, 2), dtype=float32, numpy=
# array([[[[-5.87671757e+00,  4.21852875e+00],
#          [-4.71974897e+00,  3.61708117e+00],
#          [ 2.42645645e+00, -6.86112404e+00],
#          [-5.13641453e+00, -5.49270248e+00],
#          [-3.04745483e+00,  1.74720383e+00],
#          [-1.07266827e+01, -4.15802956e+00],
#          [-5.07461834e+00, -8.42529297e+00],
#          [-3.47180414e+00,  1.87668467e+00],
#          [-8.99925232e-02, -6.06565475e+00],
#          [ 4.04629612e+00, -4.61523724e+00],
#          [ 2.29399800e-02,  7.71245337e+00],
#          [-2.04247618e+00, -3.64089155e+00],
#          [ 3.42437601e+00,  1.61334682e+00],
#          [ 1.05450134e+01, -5.40924740e+00],
#          [ 7.94891834e+00,  4.43398905e+00],
#          [ 8.56489182e+00,  1.05496955e+00],
#          [ 5.75496149e+00,  7.84438658e+00],
#          [-2.46995010e+01, -8.38440514e+00],
#          [-4.56770897e+00,  3.39747715e+00],
#          [-3.08433676e+00, -1.17570817e+00],
#          [ 1.25443430e+01,  7.17982829e-01],
#          [ 9.98424625e+00,  4.16341257e+00],
#          [ 4.32715356e-01,  2.83007669e+00]],
#
#         [[ 1.38788061e+01,  1.08610687e+01],
#          [-4.81571341e+00, -1.32809401e+00],
#          [-4.35685158e+00,  1.21484385e+01],
#          [ 1.70455039e+00, -2.44053888e+00],
#          [-1.44278193e+00, -9.42051601e+00],
#          [ 3.90953016e+00, -8.82821083e+00],
#          [-3.80715322e+00, -1.07054892e+01],
#          [ 2.73228884e+00,  6.87897682e+00],
#          [ 6.18200970e+00, -1.29606943e+01],
#          [ 5.66671848e-01, -7.92224789e+00],
#          [ 5.77291727e-01, -2.48412657e+00],
#          [ 6.39575291e+00, -7.45656490e+00],
#          [-1.17979898e+01, -3.83135009e+00],
#          [ 4.79530239e+00,  2.62999344e+00],
#          [-1.01213002e+00,  5.65989065e+00],
#          [-1.20268450e+01,  2.30258441e+00]],
#
#         [[ 2.40462732e+00,  1.65030360e+00],
#          [-1.81655407e-01,  6.07497692e-01],
#          [ 6.02797794e+00, -2.73990345e+00],
#          [ 6.20915174e-01, -4.16621447e-01],
#          [ 7.99287891e+00,  5.77966022e+00],
#          [ 1.12115514e+00, -1.06984878e+00],
#          [-1.79049730e-01,  1.35469818e+00],
#          [-2.52021194e+00, -7.13008404e+00],
#          [-2.33506370e+00, -6.55067444e+00],
#          [ 2.44987583e+00,  1.87877655e+00],
#          [-6.07315159e+00,  4.66183376e+00],
#          [ 3.23259139e+00,  1.21308413e+01],
#          [ 2.21901536e+00,  6.29769802e+00],
#          [-4.33100939e+00, -1.15069580e+00],
#          [ 3.46643019e+00, -2.77703118e+00],
#          [ 6.91163826e+00, -2.13657308e+00],
#          [ 6.00297403e+00,  5.94247723e+00],
#          [ 1.21220112e-01,  8.09668303e-01],
#          [-8.93605232e+00,  2.45741487e-01],
#          [ 5.42414427e+00,  6.08817720e+00],
#          [-8.62838459e+00, -1.06480665e+01],
#          [ 2.87691760e+00,  5.22496700e+00],
#          [ 3.99193335e+00,  6.04195404e+00]],
#
#         [[-1.31418276e+00, -2.12134123e-01],
#          [-3.27308083e+00,  2.66275024e+00],
#          [-2.28303552e+00, -3.89640546e+00],
#          [-7.26476908e+00, -4.30549574e+00],
#          [-2.37176895e+00, -1.33929920e+00],
#          [-1.52474165e-01, -4.99435902e+00],
#          [-5.25641775e+00, -1.50379944e+00],
#          [-4.95300865e+00, -5.15689421e+00],
#          [ 2.31087613e+00,  2.44088793e+00],
#          [ 3.17018628e+00, -3.06762552e+00],
#          [-1.59254742e+00,  9.00240958e-01],
#          [-7.81735992e+00,  2.65056372e+00],
#          [ 4.07119036e+00,  5.88015079e+00],
#          [-5.55245399e+00, -2.56640816e+00],
#          [ 3.32202578e+00, -3.96292520e+00],
#          [ 5.10301018e+00, -1.82035637e+00],
#          [ 5.90352821e+00, -9.74082470e-01],
#          [-6.58275127e-01,  2.59160447e+00],
#          [-9.29645157e+00,  2.12942505e+00],
#          [-4.26870060e+00, -7.24434853e-02],
#          [-4.59306002e+00, -2.22097588e+00],
#          [-1.97982144e+00, -6.38092661e+00],
#          [ 8.63931084e+00, -3.37117362e+00]]]], dtype=float32)>

# %%
w1=tf.Variable(tf.random.truncated_normal([784,256],stddev=0.1))

# %%
b1=tf.Variable(tf.zeros([256]))

# %%
w2=tf.Variable(tf.random.truncated_normal([256,128],stddev=0.1))

# %%
b2=tf.Variable(tf.zeros([10]))

# %%
x=tf.reshape(x,[-1,28*28])
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-40-a7d8727fd463> in <module>()
# ----> 1 x=tf.reshape(x,[-1,28*28])
#
# D:\anaconda\lib\site-packages\tensorflow_core\python\ops\array_ops.py in reshape(tensor, shape, name)
#     129     A `Tensor`. Has the same type as `tensor`.
#     130   """
# --> 131   result = gen_array_ops.reshape(tensor, shape, name)
#     132   tensor_util.maybe_set_static_shape(result, shape)
#     133   return result
#
# D:\anaconda\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in reshape(tensor, shape, name)
#    8103       try:
#    8104         return reshape_eager_fallback(
# -> 8105             tensor, shape, name=name, ctx=_ctx)
#    8106       except _core._SymbolicException:
#    8107         pass  # Add nodes to the TensorFlow graph.
#
# D:\anaconda\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in reshape_eager_fallback(tensor, shape, name, ctx)
#    8141   _attrs = ("T", _attr_T, "Tshape", _attr_Tshape)
#    8142   _result = _execute.execute(b"Reshape", 1, inputs=_inputs_flat, attrs=_attrs,
# -> 8143                              ctx=_ctx, name=name)
#    8144   _execute.record_gradient(
#    8145       "Reshape", _inputs_flat, _attrs, _result, name)
#
# D:\anaconda\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# D:\anaconda\lib\site-packages\six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Input to reshape is a tensor with 2 values, but the requested shape requires a multiple of 784 [Op:Reshape]

# %%
h1=x@w1+tf.broadcast_to(b1,[x.shape[0],256])
h1=tf.nn.relu(h1)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-41-85ede21f1fa1> in <module>()
# ----> 1 h1=x@w1+tf.broadcast_to(b1,[x.shape[0],256])
#       2 h1=tf.nn.relu(h1)
#
# D:\anaconda\lib\site-packages\tensorflow_core\python\ops\math_ops.py in binary_op_wrapper(x, y)
#     910           else:
#     911             raise
# --> 912       return func(x, y, name=name)
#     913
#     914   def binary_op_wrapper_sparse(sp_x, y):
#
# D:\anaconda\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# D:\anaconda\lib\site-packages\tensorflow_core\python\ops\math_ops.py in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, name)
#    2763     else:
#    2764       return gen_math_ops.mat_mul(
# -> 2765           a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    2766
#    2767
#
# D:\anaconda\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    6123       else:
#    6124         message = e.message
# -> 6125       _six.raise_from(_core._status_to_exception(e.code, message), None)
#    6126   # Add nodes to the TensorFlow graph.
#    6127   if transpose_a is None:
#
# D:\anaconda\lib\site-packages\six.py in raise_from(value, from_value)
#
# InvalidArgumentError: In[0] is not a matrix. Instead it has shape [2] [Op:MatMul] name: matmul/

# %%
h2=h1@w2+b2
h2=tf.nn.relu(h2)
out=h2@w3+b3
loss=tf.square(y_onehot-out)
loss=tf.reduce_mean(loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-5b2e8b22eb94> in <module>()
# ----> 1 h2=h1@w2+b2
#       2 h2=tf.nn.relu(h2)
#       3 out=h2@w3+b3
#       4 loss=tf.square(y_onehot-out)
#       5 loss=tf.reduce_mean(loss)
#
# NameError: name 'h1' is not defined
