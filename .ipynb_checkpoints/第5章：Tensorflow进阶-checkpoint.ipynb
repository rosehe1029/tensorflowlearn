# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
points=[]
for  x in range(-8,8,100):
    for y in range(-8,8,100):
        z=sinc(x,y)
        points.append([x,y,z])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e2f9d56cc1e> in <module>()
#       2 for  x in range(-8,8,100):
#       3     for y in range(-8,8,100):
# ----> 4         z=sinc(x,y)
#       5         points.append([x,y,z])
#       6
#
# NameError: name 'sinc' is not defined

# %%
z=tf.sqrt(x**2+y**2)
z=tf.sin(z)/z
fig=plt.figure()
ax=Axes3D(fig)
ax.contour3D(x.numpy(),y.numpy(),z.numpy(),50)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-354ebdda9d59> in <module>()
# ----> 1 z=tf.sqrt(x**2+y**2)
#       2 z=tf.sin(z)/z
#       3 fig=plt.figure()
#       4 ax=Axes3D(fig)
#       5 ax.contour3D(x.numpy(),y.numpy(),z.numpy(),50)
#
# NameError: name 'tf' is not defined
